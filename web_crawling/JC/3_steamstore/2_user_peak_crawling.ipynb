# %%
import urllib
import json
from bs4 import BeautifulSoup 
import requests
import pandas as pd
import os
from glob import glob

# %%
# 현재 작업중인 디렉토리 cwd
cwd = os.getcwd()
print("현재 작업중인 디렉토리", cwd)

# 파일과 폴더 확인
folder_check = os.listdir(r"C:\Users\alice\OneDrive\바탕화~1-DESKTOP-K2BRIJ8-1984\ASAC_ml_project\ASAC_ml_project\web_crawling\JC")
print("파일과 폴더 확인:", folder_check)

# cwd 상위 폴더 확인
parent = os.path.dirname(cwd)
print("상위 폴더 확인 : ", parent)
# Out:
# 현재 작업중인 디렉토리 c:\Users\alice\OneDrive\바탕화~1-DESKTOP-K2BRIJ8-1984\ASAC_ml_project\ASAC_ml_project\web_crawling\JC\3_steamstore
# 파일과 폴더 확인: ['1_appid', '2_steampy_tag', '3_steamstore']
# 상위 폴더 확인 :  c:\Users\alice\OneDrive\바탕화~1-DESKTOP-K2BRIJ8-1984\ASAC_ml_project\ASAC_ml_project\web_crawling\JC

# %% [markdown]
# # 상대경로를 이용해서 순회하기
# glob
# for

# %%
# 1) 필욱님 코드
f = open(r"C:\Users\alice\OneDrive\바탕화~1-DESKTOP-K2BRIJ8-1984\ASAC_ml_project\ASAC_ml_project\web_crawling\JC\1_appid\appid_2022.txt")
app_id = []
User = []

# app_id 모으기 
while True:
    line = f.readline()
    if not line:
        break
    app_id.append(line.strip())

# %%
for i in range(len(app_id)):
    
    url = "https://steamcharts.com/app/"+str(app_id[i])
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    # 결측치 처리(?)
    peak_24 = "Invalid"
    peak_all = "Invalid"
    
    # peak_24가 존재한다면 정보 가져오기
    if len(soup.select("#app-heading > dif:nth-child(3) > span")) !=0:

# %%
sample_url = "https://steamcharts.com/app/1097150"

response = requests.get(sample_url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Fall Guys - Steam Charts
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="An ongoing analysis of Steam's player numbers, seeing what's been played the most." name="description"/>
#   <meta content="4503599630058963" property="twitter:account_id"/>
#   <meta content="@steamcharts" name="twitter:site"/>
#   <meta content="Fall Guys - Steam Charts" name="twitter:title"/>
#   <meta content="http://steamcharts.com/app/1097150" name="twitter:url"/>
#   <script async="" site="steam-charts" src="https://kumo.network-n.com/dist/app.js">
#   </script>
#   <link href="/assets/style-9826f406.css" rel="stylesheet"/>
#   <script src="/assets/script-88db269a.js">
#   </script>
#   <link href="/assets/favicon.ico" rel="shortcut icon"/>
#  </head>
#  <body>
#   <div id="nn_skinl">
#   </div>
#   <div id="nn_skinr">
#   </div>
#   <div id="content-wrapper">
#    <div id="header">
#     <a href="/" id="logo">
#      <span id="logo-steam">
#       STEAM
#      </span>
#      <span id="logo-charts">
#       CHARTS
#      </span>
#     </a>
#     <i>
#      An ongoing analysis of Steam's concurrent players.
#     </i>
#     <div style="float: right">
#      <form action="/search/" class="inline" id="search" role="search">
#       <input name="q" placeholder="search games" type="text"/>
#      </form>
#     </div>
#    </div>
#    <h1 id="app-title">
#     <a href="">
#      Fall Guys
#     </a>
#    </h1>
#    <div id="app-links">
#     <a href="http://store.steampowered.com/app/1097150/">
#      Store
#     </a>
#     |
#     <a href="http://steamcommunity.com/app/1097150">
#      Hub
#     </a>
#    </div>
#    <div class="content" id="app-heading">
#     <img alt="Fall Guys" class="app-image" height="69" src="/assets/steam-images/1097150.jpg" width="184"/>
#     <div class="app-stat">
#      <span class="num">
#       3598
#      </span>
#      <br/>
#      playing
#      <abbr class="timeago" title="2023-05-21T04:02:19Z">
#      </abbr>
#     </div>
#     <div class="app-stat">
#      <span class="num">
#       4276
#      </span>
#      <br/>
#      24-hour peak
#     </div>
#     <div class="app-stat">
#      <span class="num">
#       172026
#      </span>
#      <br/>
#      all-time peak
#     </div>
#    </div>
#    <div class="content" id="app-hours-content">
#     <div id="app-longterm-chart">
#     </div>
#     <div style="float: right; margin: 0; padding: 0">
#      <a href="/cmp/1097150">
#       Compare with others...
#      </a>
#     </div>
#    </div>
#    <div class="ad720">
#     <div id="nn_lb1">
#     </div>
#    </div>
#    <div class="content">
#     <table class="common-table">
#      <thead>
#       <tr>
#        <th class="left">
#         Month
#        </th>
#        <th class="right">
#         Avg. Players
#        </th>
#        <th class="right">
#         Gain
#        </th>
#        <th class="right">
#         % Gain
#        </th>
#        <th class="right">
#         Peak Players
#        </th>
#       </tr>
#      </thead>
#      <tbody>
#       <tr class="odd">
#        <td class="month-cell left italic">
#         Last 30 Days
#        </td>
#        <td class="right num-f italic">
#         2599.38
#        </td>
#        <td class="right num-p gainorloss italic">
#         +433.9
#        </td>
#        <td class="right gainorloss italic">
#         +20.03%
#        </td>
#        <td class="right num italic">
#         5672
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         April 2023
#        </td>
#        <td class="right num-f">
#         2165.53
#        </td>
#        <td class="right num-p gainorloss">
#         -159.56
#        </td>
#        <td class="right gainorloss">
#         -6.86%
#        </td>
#        <td class="right num">
#         3443
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         March 2023
#        </td>
#        <td class="right num-f">
#         2325.08
#        </td>
#        <td class="right num-p gainorloss">
#         -372.94
#        </td>
#        <td class="right gainorloss">
#         -13.82%
#        </td>
#        <td class="right num">
#         3711
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         February 2023
#        </td>
#        <td class="right num-f">
#         2698.03
#        </td>
#        <td class="right num-p gainorloss">
#         -886.25
#        </td>
#        <td class="right gainorloss">
#         -24.73%
#        </td>
#        <td class="right num">
#         4386
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         January 2023
#        </td>
#        <td class="right num-f">
#         3584.27
#        </td>
#        <td class="right num-p gainorloss">
#         -577.19
#        </td>
#        <td class="right gainorloss">
#         -13.87%
#        </td>
#        <td class="right num">
#         5399
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         December 2022
#        </td>
#        <td class="right num-f">
#         4161.46
#        </td>
#        <td class="right num-p gainorloss">
#         231.37
#        </td>
#        <td class="right gainorloss">
#         +5.89%
#        </td>
#        <td class="right num">
#         9974
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         November 2022
#        </td>
#        <td class="right num-f">
#         3930.09
#        </td>
#        <td class="right num-p gainorloss">
#         -1706.91
#        </td>
#        <td class="right gainorloss">
#         -30.28%
#        </td>
#        <td class="right num">
#         7035
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         October 2022
#        </td>
#        <td class="right num-f">
#         5637.00
#        </td>
#        <td class="right num-p gainorloss">
#         -2982.22
#        </td>
#        <td class="right gainorloss">
#         -34.60%
#        </td>
#        <td class="right num">
#         12443
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         September 2022
#        </td>
#        <td class="right num-f">
#         8619.22
#        </td>
#        <td class="right num-p gainorloss">
#         -5790.96
#        </td>
#        <td class="right gainorloss">
#         -40.19%
#        </td>
#        <td class="right num">
#         18591
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         August 2022
#        </td>
#        <td class="right num-f">
#         14410.18
#        </td>
#        <td class="right num-p gainorloss">
#         -15390.83
#        </td>
#        <td class="right gainorloss">
#         -51.65%
#        </td>
#        <td class="right num">
#         25576
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         July 2022
#        </td>
#        <td class="right num-f">
#         29801.01
#        </td>
#        <td class="right num-p gainorloss">
#         12329.06
#        </td>
#        <td class="right gainorloss">
#         +70.56%
#        </td>
#        <td class="right num">
#         52870
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         June 2022
#        </td>
#        <td class="right num-f">
#         17471.95
#        </td>
#        <td class="right num-p gainorloss">
#         11093.89
#        </td>
#        <td class="right gainorloss">
#         +173.94%
#        </td>
#        <td class="right num">
#         59554
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         May 2022
#        </td>
#        <td class="right num-f">
#         6378.06
#        </td>
#        <td class="right num-p gainorloss">
#         -316.13
#        </td>
#        <td class="right gainorloss">
#         -4.72%
#        </td>
#        <td class="right num">
#         12277
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         April 2022
#        </td>
#        <td class="right num-f">
#         6694.20
#        </td>
#        <td class="right num-p gainorloss">
#         -1716.85
#        </td>
#        <td class="right gainorloss">
#         -20.41%
#        </td>
#        <td class="right num">
#         17749
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         March 2022
#        </td>
#        <td class="right num-f">
#         8411.04
#        </td>
#        <td class="right num-p gainorloss">
#         2292.07
#        </td>
#        <td class="right gainorloss">
#         +37.46%
#        </td>
#        <td class="right num">
#         19968
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         February 2022
#        </td>
#        <td class="right num-f">
#         6118.98
#        </td>
#        <td class="right num-p gainorloss">
#         -2081.14
#        </td>
#        <td class="right gainorloss">
#         -25.38%
#        </td>
#        <td class="right num">
#         9928
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         January 2022
#        </td>
#        <td class="right num-f">
#         8200.12
#        </td>
#        <td class="right num-p gainorloss">
#         -469.38
#        </td>
#        <td class="right gainorloss">
#         -5.41%
#        </td>
#        <td class="right num">
#         15741
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         December 2021
#        </td>
#        <td class="right num-f">
#         8669.50
#        </td>
#        <td class="right num-p gainorloss">
#         2375.38
#        </td>
#        <td class="right gainorloss">
#         +37.74%
#        </td>
#        <td class="right num">
#         15901
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         November 2021
#        </td>
#        <td class="right num-f">
#         6294.12
#        </td>
#        <td class="right num-p gainorloss">
#         -720.35
#        </td>
#        <td class="right gainorloss">
#         -10.27%
#        </td>
#        <td class="right num">
#         14674
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         October 2021
#        </td>
#        <td class="right num-f">
#         7014.47
#        </td>
#        <td class="right num-p gainorloss">
#         -3900.73
#        </td>
#        <td class="right gainorloss">
#         -35.74%
#        </td>
#        <td class="right num">
#         16668
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         September 2021
#        </td>
#        <td class="right num-f">
#         10915.20
#        </td>
#        <td class="right num-p gainorloss">
#         300.42
#        </td>
#        <td class="right gainorloss">
#         +2.83%
#        </td>
#        <td class="right num">
#         27277
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         August 2021
#        </td>
#        <td class="right num-f">
#         10614.78
#        </td>
#        <td class="right num-p gainorloss">
#         934.07
#        </td>
#        <td class="right gainorloss">
#         +9.65%
#        </td>
#        <td class="right num">
#         18976
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         July 2021
#        </td>
#        <td class="right num-f">
#         9680.71
#        </td>
#        <td class="right num-p gainorloss">
#         3079.14
#        </td>
#        <td class="right gainorloss">
#         +46.64%
#        </td>
#        <td class="right num">
#         18225
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         June 2021
#        </td>
#        <td class="right num-f">
#         6601.58
#        </td>
#        <td class="right num-p gainorloss">
#         -509.88
#        </td>
#        <td class="right gainorloss">
#         -7.17%
#        </td>
#        <td class="right num">
#         13775
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         May 2021
#        </td>
#        <td class="right num-f">
#         7111.46
#        </td>
#        <td class="right num-p gainorloss">
#         -1550.61
#        </td>
#        <td class="right gainorloss">
#         -17.90%
#        </td>
#        <td class="right num">
#         11886
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         April 2021
#        </td>
#        <td class="right num-f">
#         8662.07
#        </td>
#        <td class="right num-p gainorloss">
#         -538.48
#        </td>
#        <td class="right gainorloss">
#         -5.85%
#        </td>
#        <td class="right num">
#         16257
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         March 2021
#        </td>
#        <td class="right num-f">
#         9200.54
#        </td>
#        <td class="right num-p gainorloss">
#         163.59
#        </td>
#        <td class="right gainorloss">
#         +1.81%
#        </td>
#        <td class="right num">
#         23065
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         February 2021
#        </td>
#        <td class="right num-f">
#         9036.95
#        </td>
#        <td class="right num-p gainorloss">
#         -1908.26
#        </td>
#        <td class="right gainorloss">
#         -17.43%
#        </td>
#        <td class="right num">
#         16645
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         January 2021
#        </td>
#        <td class="right num-f">
#         10945.21
#        </td>
#        <td class="right num-p gainorloss">
#         -2424.56
#        </td>
#        <td class="right gainorloss">
#         -18.13%
#        </td>
#        <td class="right num">
#         20457
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         December 2020
#        </td>
#        <td class="right num-f">
#         13369.77
#        </td>
#        <td class="right num-p gainorloss">
#         576.97
#        </td>
#        <td class="right gainorloss">
#         +4.51%
#        </td>
#        <td class="right num">
#         28612
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         November 2020
#        </td>
#        <td class="right num-f">
#         12792.80
#        </td>
#        <td class="right num-p gainorloss">
#         -13645.66
#        </td>
#        <td class="right gainorloss">
#         -51.61%
#        </td>
#        <td class="right num">
#         22737
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         October 2020
#        </td>
#        <td class="right num-f">
#         26438.47
#        </td>
#        <td class="right num-p gainorloss">
#         -40461.01
#        </td>
#        <td class="right gainorloss">
#         -60.48%
#        </td>
#        <td class="right num">
#         83964
#        </td>
#       </tr>
#       <tr class="odd">
#        <td class="month-cell left">
#         September 2020
#        </td>
#        <td class="right num-f">
#         66899.48
#        </td>
#        <td class="right num-p gainorloss">
#         -57579.87
#        </td>
#        <td class="right gainorloss">
#         -46.26%
#        </td>
#        <td class="right num">
#         150587
#        </td>
#       </tr>
#       <tr>
#        <td class="month-cell left">
#         August 2020
#        </td>
#        <td class="right num-f">
#         124479.35
#        </td>
#        <td class="right num-p gainorloss">
#         -
#        </td>
#        <td class="right gainorloss">
#         -
#        </td>
#        <td class="right num">
#         172026
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <script>
#     d3.selectAll('.num').text(app.formatText);
# 	d3.selectAll('.num-f').text(app.formatF1Text);
# 	d3.selectAll('.num-p').text(app.formatPlusText);
# 	d3.selectAll('.gainorloss').classed('gain',
# 	function() { var text = this.textContent; return (text.length > 1 && text[0] == '+');})
# 		.classed('loss',
# 	function() { var text = this.textContent; return (text.length > 1 && text[0] == '-');});
#
# 	$('abbr.timeago').timeago();
#
# 	$.getJSON('/app/1097150/chart-data.json', function(data) {
# 		app.gameChart('app-longterm-chart', ["Fall Guys"], [data]);
# 	});
#    </script>
#    <div>
#     <div style="float: left; width:410px">
#      <a class="twitter-timeline" data-widget-id="518237975872684032" href="https://twitter.com/steamcharts">
#       Tweets by @steamcharts
#      </a>
#      <script>
#       !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#      </script>
#     </div>
#     <div style="float: right">
#      <div id="nn_mpu1">
#      </div>
#     </div>
#     <div style="clear:both">
#     </div>
#    </div>
#    <div id="footer">
#     <a href="/about">
#      About
#     </a>
#     |
#     <a href="/privacy">
#      Privacy
#     </a>
#     |
#     <a href="/ads">
#      Advertise
#     </a>
#    </div>
#    <div id="closing">
#     All data is
#     <a href="http://steampowered.com">
#      powered by Steam
#     </a>
#     . Not affiliated with Valve in any way. All trademarks are property of their respective owners in the US and other countries. Our goal is to provide unique insight into gaming trends. © steamcharts.com
#    </div>
#   </div>
#   <script type="text/javascript">
#    !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-2224718-9', 'steamcharts.com');
# ga('create', 'UA-31105670-10', 'auto', {'name': 'pcn'});
# ga('send', 'pageview');
# ga('pcn.send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
appid_dirs = glob(f'{parent}\\**\\appid_list\\*.txt',recursive=True)
print(appid_dirs)
# Out:
# []

# %%
# 2) 성현님 코드 appid_연도.txt에서 app id 가져오기

# 1_appid라는 이름이 포함되있는 txt 파일경로를 리스트로 가져옴(recursive=True로 하고 ** 쓰면 하위폴더까지 전부 검색)
appid_dirs = glob(f'{parent}\\**\\appid_list\\*.txt',recursive=True)

for appid_dir in appid_dirs:
    # appid_dir.txt를 줄 기준으로 읽어 온뒤 \n(엔터키)를 제거
    # open(appid_dir).readlines()의 출력은 ['~~~~\n', '~~~~\n' .....] 이런식
    app_list = [i.replace('\n', '') for i in open(appid_dir).readlines()]
    print(app_list)
    
for app in app_list:
    print(app)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 11
#       9     app_list = [i.replace('\n', '') for i in open(appid_dir).readlines()]
#      10     print(app_list)
# ---> 11 for app in app_list:
#      12     print(app)
#
# NameError: name 'app_list' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 for app in app_list:
#       2     print(app)
#
# NameError: name 'app_list' is not defined
